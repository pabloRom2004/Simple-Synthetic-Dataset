# %%
from preprocessors import ReadingLevelPreprocessor
calculator = ReadingLevelPreprocessor()

# Use with:
score = calculator.calculate_reading_metrics("The reoffending rate in Sweden is between 30 and 40%  to compare that with another European country, the number is around half that of the UK.")
score
# Out:
# 56.798846153846185
